# %%
from online_retail_simulator import simulate

# %%
df_products, df_sales = simulate("config_synthesizer.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_products, df_sales = simulate("config_synthesizer.json")
#
# File ~/office/business/eisenhauer-io/tools/catalog-generator/online_retail_simulator/simulator.py:30, in simulate(config_path, mode, **kwargs)
#      28 if sim_mode == "synthesizer":
#      29     from .simulator_synthesizer_based import simulate_synthesizer_based
# ---> 30     return simulate_synthesizer_based(config_path, config=config, **kwargs)
#      31 raise ValueError("mode must be 'rule' or 'synthesizer'")
#
# File ~/office/business/eisenhauer-io/tools/catalog-generator/online_retail_simulator/simulator_synthesizer_based.py:147, in simulate_synthesizer_based(config_path, num_rows_products, num_rows_sales, config)
#     141     raise ValueError(
#     142         "Row counts must be provided as arguments or in config as "
# ...

# %%
df_products.head()
# Out:
#   product_id       name     category   price
# 0   PROD0001    T-Shirt     Clothing  152.19
# 1   PROD0002  Biography        Books   16.98
# 2   PROD0003      Jeans     Clothing  124.24
# 3   PROD0004     Laptop  Electronics  185.86
# 4   PROD0005      Novel        Books   38.06

# %%
df_sales.query("product_id == 'PROD0001'").sort_values("date")
# Out:
#      product_id        date  quantity  revenue
# 0      PROD0001  2024-11-01         1   152.19
# 50     PROD0001  2024-11-02         3   456.57
# 100    PROD0001  2024-11-03         1   152.19
# 150    PROD0001  2024-11-04         0     0.00
# 200    PROD0001  2024-11-05         0     0.00
# 250    PROD0001  2024-11-06         1   152.19
# 300    PROD0001  2024-11-07         3   456.57
# 350    PROD0001  2024-11-08         0     0.00
# 400    PROD0001  2024-11-09         2   304.38
# 450    PROD0001  2024-11-10         1   152.19
# 500    PROD0001  2024-11-11         0     0.00
# 550    PROD0001  2024-11-12         0     0.00
# 600    PROD0001  2024-11-13         3   456.57
# 650    PROD0001  2024-11-14         3   456.57
# 700    PROD0001  2024-11-15         3   456.57
# 750    PROD0001  2024-11-16         2   304.38
# 800    PROD0001  2024-11-17         1   152.19
# 850    PROD0001  2024-11-18         1   152.19
# 900    PROD0001  2024-11-19         0     0.00
# ...
