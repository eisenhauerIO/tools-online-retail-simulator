# %%
from online_retail_simulator import simulate

# %%
df = simulate("config_rule.json")
# Out:
# ...
# Online Retail Simulator
# ...
#
# Configuration:
#   Seed:         42
#   Products:     50
#   Date Range:   2024-11-01 to 2024-11-30
#   Output Dir:   demo/output
#
# Generating 50 products...
# ✓ Generated 50 products
#
# Generating baseline sales transactions...
# ✓ Generated 1071 baseline transactions
#
# Saving baseline data to demo/output/...
# Data saved to demo/output/rb_demo_products.json
# Data saved to demo/output/rb_demo_sales.json
#
# ...
# Summary
# ...
# Total Products:     50
# Product Categories: 8
# Total Transactions: 1071
# Days with Sales:    30
# Total Units Sold:   2051
# Total Revenue:      $310,859.51
# Average Order:      $290.25
#
# ✓ Simulation complete!

# %%
# Out:
# tuple
